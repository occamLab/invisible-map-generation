# %% [markdown]
# # Experiment One (MAC)
# The purpose of this experiment is to evaluate the relative accuracy and success rate of the tuned hyperparameters for a given map. This evaluation will be done in three main methods:
# 1. Determine the lowest ground truth value for a given map based on a parameter sweep.
# 2. Determine if the tuned hyperparameters of one map can be extrapolated to that of another map that either contains this map or is contained within this map.
# 3. Determine if there is a smooth relationship between a swept hyperparameter and the ground truth data.
#
# Each of these specific tests will be conducted twice - once with SBA optimization and once without.

# %% [markdown]
# Run the following script to set up the notebook environment before running any other code cells.

# %%
# %cd ../..
import os
import sys
sys.path.append(os.getcwd() + "/../..")
from run_scripts.run import extrapolate_parameters, run_sweep
small_map_name = 'r1-five-straight-elevator-3rounds.json'
big_map_name = 'r1-five-straight-3rounds.json'
# Out:
# /home/achakraborty/Documents/occam/invisible-map-generation

# %% [markdown]
# The first test being conducted is determining the minimum ground truth of an optimized map with a no SBA optimization. This is being done on both, a small map and a large map.

# %%
run_sweep(small_map_name, 1)
# Out:
# Generating list of optimization sweeping parameters...
# 1000 parameters generated for sweeping
# Starting multi-process optimization parameter sweep (with 8 processes)...
#   0%|          | 0/1000 [00:00<?, ?it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   0%|          | 1/1000 [00:01<30:07,  1.81s/it]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   0%|          | 3/1000 [00:03<16:27,  1.01it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   0%|          | 5/1000 [00:04<13:57,  1.19it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   1%|          | 6/1000 [00:05<15:44,  1.05it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   1%|          | 10/1000 [00:07<07:05,  2.33it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#  20%|█▉        | 198/1000 [03:24<13:48,  1.03s/it]
# PYDANTIC ERROR
#  32%|███▏      | 323/1000 [04:30<04:45,  2.37it/s]
# PYDANTIC ERROR
#  32%|███▏      | 324/1000 [04:30<04:08,  2.72it/s]
#  40%|███▉      | 399/1000 [05:01<04:12,  2.38it/s]
# PYDANTIC ERROR
#  44%|████▍     | 444/1000 [05:19<04:17,  2.16it/s]
# PYDANTIC ERROR
#  50%|█████     | 502/1000 [05:42<02:41,  3.08it/s]
# PYDANTIC ERROR
#  51%|█████▏    | 513/1000 [05:47<03:31,  2.31it/s]
# PYDANTIC ERROR
#  51%|█████▏    | 514/1000 [05:47<02:55,  2.77it/s]
#  52%|█████▏    | 524/1000 [05:51<02:31,  3.14it/s]
# PYDANTIC ERROR
#  57%|█████▋    | 567/1000 [06:09<02:22,  3.03it/s]
# PYDANTIC ERROR
#  60%|██████    | 602/1000 [06:23<02:24,  2.75it/s]
# PYDANTIC ERROR
#  60%|██████    | 605/1000 [06:23<01:48,  3.65it/s]
# PYDANTIC ERROR
#  61%|██████▏   | 613/1000 [06:27<01:55,  3.35it/s]
# PYDANTIC ERROR
#  62%|██████▏   | 616/1000 [06:28<02:51,  2.24it/s]
# PYDANTIC ERROR
#  62%|██████▏   | 619/1000 [06:29<01:51,  3.42it/s]
# PYDANTIC ERROR
#  62%|██████▏   | 623/1000 [06:31<02:27,  2.55it/s]
# PYDANTIC ERROR
#  63%|██████▎   | 634/1000 [06:35<02:13,  2.73it/s]
# PYDANTIC ERROR
#  64%|██████▍   | 644/1000 [06:39<02:58,  1.99it/s]
# PYDANTIC ERROR
#  70%|██████▉   | 698/1000 [07:02<02:32,  1.98it/s]
# PYDANTIC ERROR
#  70%|███████   | 704/1000 [07:03<01:13,  4.05it/s]
# PYDANTIC ERROR
#  71%|███████   | 712/1000 [07:06<01:10,  4.10it/s]
# PYDANTIC ERROR
#  71%|███████▏  | 714/1000 [07:08<02:15,  2.12it/s]
# PYDANTIC ERROR
#  72%|███████▏  | 721/1000 [07:10<02:15,  2.07it/s]
# PYDANTIC ERROR
#  73%|███████▎  | 727/1000 [07:12<01:28,  3.07it/s]
# PYDANTIC ERROR
#  73%|███████▎  | 733/1000 [07:15<01:43,  2.58it/s]
# PYDANTIC ERROR
#  74%|███████▎  | 737/1000 [07:16<01:22,  3.18it/s]
# PYDANTIC ERROR
#  75%|███████▍  | 746/1000 [07:20<01:12,  3.48it/s]
# PYDANTIC ERROR
#  76%|███████▌  | 755/1000 [07:24<01:37,  2.52it/s]
# PYDANTIC ERROR
#  77%|███████▋  | 767/1000 [07:28<01:11,  3.27it/s]
# PYDANTIC ERROR
#  80%|████████  | 801/1000 [07:42<00:47,  4.21it/s]
# PYDANTIC ERROR
#  80%|████████  | 802/1000 [07:43<01:33,  2.13it/s]
# PYDANTIC ERROR
#  81%|████████  | 811/1000 [07:46<01:10,  2.67it/s]
# PYDANTIC ERROR
#  81%|████████  | 812/1000 [07:47<01:42,  1.83it/s]
#  82%|████████▏ | 817/1000 [07:48<00:57,  3.20it/s]
# PYDANTIC ERROR
#  82%|████████▏ | 822/1000 [07:51<01:14,  2.40it/s]
# PYDANTIC ERROR
#  83%|████████▎ | 827/1000 [07:52<00:53,  3.22it/s]
# PYDANTIC ERROR
#  83%|████████▎ | 834/1000 [07:55<00:48,  3.42it/s]
# PYDANTIC ERROR
#  84%|████████▍ | 838/1000 [07:57<01:02,  2.58it/s]
# PYDANTIC ERROR
#  84%|████████▍ | 842/1000 [07:58<00:38,  4.06it/s]
# PYDANTIC ERROR
#  85%|████████▌ | 853/1000 [08:03<01:12,  2.03it/s]
# PYDANTIC ERROR
#  87%|████████▋ | 867/1000 [08:08<00:41,  3.23it/s]
# PYDANTIC ERROR
#  90%|█████████ | 901/1000 [08:22<00:32,  3.05it/s]
# PYDANTIC ERROR
#  90%|█████████ | 905/1000 [08:24<00:33,  2.83it/s]
# PYDANTIC ERROR
#  91%|█████████ | 912/1000 [08:27<00:36,  2.43it/s]
# PYDANTIC ERROR
#  91%|█████████▏| 913/1000 [08:27<00:31,  2.77it/s]
#  92%|█████████▏| 916/1000 [08:28<00:22,  3.77it/s]
# PYDANTIC ERROR
#  92%|█████████▎| 925/1000 [08:31<00:20,  3.67it/s]
# PYDANTIC ERROR
#  93%|█████████▎| 927/1000 [08:33<00:40,  1.79it/s]
# PYDANTIC ERROR
#  94%|█████████▎| 935/1000 [08:36<00:23,  2.71it/s]
# PYDANTIC ERROR
#  94%|█████████▎| 936/1000 [08:36<00:24,  2.63it/s]
# PYDANTIC ERROR
#  94%|█████████▍| 945/1000 [08:40<00:24,  2.29it/s]
# PYDANTIC ERROR
#  96%|█████████▌| 956/1000 [08:44<00:16,  2.62it/s]
# PYDANTIC ERROR
#  97%|█████████▋| 968/1000 [08:49<00:15,  2.04it/s]
# PYDANTIC ERROR
# 100%|██████████| 1000/1000 [09:02<00:00,  1.84it/s]
# Pre-Optimization GT: 0.08594258312404719
# Best GT: 0.07922716107554384 (delta: -0.006715422048503353
# Best Alpha: inf
# Pre-Optimization GT: 0.08594258312404719
# For map based on min alpha, GT: 0.13710511255211086 (delta = 0.051162529428063666)
# For map based on min gt, GT: 0.07922716107554384 (delta = -0.006715422048503353)
# For map based on min shift, GT: 0.08258966211241213 (delta = -0.0033529210116350627)
# Min Shift Metric: 0.051576482029739544
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 2e+09
# >       alpha_all_before: inf
# > se3_not_gravity_before: 2e+09
# >          psi2uv_before: 0
# >         gravity_before: 2.6e-12
# ---------------------------------
# >         chi2_all_after: 1.2e+07
# >        alpha_all_after: inf
# >  se3_not_gravity_after: 1.2e+07
# >           psi2uv_after: 0
# >          gravity_after: 0.0096
#
# Fitness metrics (Alpha):
# >        chi2_all_before: 3.7e+16
# >       alpha_all_before: inf
# > se3_not_gravity_before: 3.7e+16
# >          psi2uv_before: 0
# >         gravity_before: 2.6e-12
# ---------------------------------
# >         chi2_all_after: 9.7e+14
# >        alpha_all_after: inf
# >  se3_not_gravity_after: 9.7e+14
# >           psi2uv_after: 0
# >          gravity_after: 0.11
# Maximum ground truth metric: 0.12308738876048539 (tag id: 321.0)
# Ground Truth per Tag:
#  {307.0: 0.027331574880245738, 308.0: 0.1151500115000586, 309.0: 0.043449234823781435, 310.0: 0.08810835251491118, 311.0: 0.118046618879885, 312.0: 0.07940094374164021, 313.0: 0.06007229453948602, 320.0: 0.07729574377125704, 321.0: 0.12308738876048539, 322.0: 0.08653946014550598, 323.0: 0.06467092609325804, 324.0: 0.06757338325601135}
#
#
# Rotation metric (GT): [0.60125443 1.2965254  0.4503549 ]
# Maximum rotation (GT): [2.00086962 3.83903624 1.55448043] (tag id: 323.0)
# Rotation metric (Alpha): [3.67358966 3.22591512 0.62595726]
# Maximum rotation (Alpha): [17.56133813 11.86242102  4.50092454] (tag id: 311.0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 run_sweep(small_map_name, 1)
#
# File ~/Documents/occam/invisible-map-generation/run_scripts/run.py:51, in run_sweep(map_name, pso)
#      49 gt_dataset = cms.find_ground_truth_data_from_map_info(map_info)
#      50 sweep_config = NO_SBA_SWEEP_CONFIG if pso == 1 else SBA_SWEEP_CONFIG
# ---> 51 _ = sweep_params(
#      52     mi=map_info,
#      53     ground_truth_data=gt_dataset,
#      54     base_oconfig=OConfig(
#      55         is_sba=pso==0,
#      56         compute_inf_params=compute_inf_params,
#      57     ),
#      58     sweep_config=sweep_config,
#      59     ordered_sweep_config_keys=[key for key in sweep_config.keys()],
#      60     verbose=True,
#      61     generate_plot=True,
#      62     show_plot=True,
#      63     num_processes=8,
#      64     cms=cms,
#      65     simple_metrics=False
#      66 )
#
# File ~/Documents/occam/invisible-map-generation/map_processing/sweep.py:274, in sweep_params(mi, ground_truth_data, base_oconfig, sweep_config, ordered_sweep_config_keys, fixed_vertices, verbose, generate_plot, show_plot, num_processes, cache_results, no_sba_baseline, upload_best, cms, simple_metrics, visualize_best_map)
#     255     CacheManagerSingleton.cache_map(CacheManagerSingleton.SWEEP_PROCESSED_UPLOAD_TO, mi, processed_map_json)
#     256 if generate_plot:
#     257     # Visualize the worst anchor point from the best OResult (gt)
#     258     # optimize_graph(graph=deepcopy(sweep_results.sweep_args[min_value_idx][0]), oconfig=sweep_results.weep_args[min_value_idx][1],
#    (...)
#     272 #             if ground_truth_data is not None else None)
#     273 #
# --> 274     fig = sweep_results.visualize_results_heatmap()
#     275     if show_plot:
#     276         plt.show()
#
# File ~/Documents/occam/invisible-map-generation/map_processing/data_models.py:1607, in OSweepResults.visualize_results_heatmap(self)
#    1603 subplot_width = int(np.ceil(num_possible_slice_comb / subplot_height))
#    1605 # In each subplot, make a heatmap from the 2D cross-section of the search space that intersects the minimum
#    1606 # value
# -> 1607 where_min = self.where_min
#    1608 fig, axs = plt.subplots(subplot_height, subplot_width)
#    1609 fig.subplots_adjust(wspace=0.6, hspace=0.5)
#
# File ~/Documents/occam/invisible-map-generation/map_processing/data_models.py:1522, in OSweepResults.where_min(self)
#    1518 @property
#    1519 def where_min(self) -> Tuple[int, ...]:
#    1520 # Where minimum gt_metric
#    1521     # noinspection PyTypeChecker
# -> 1522     where_min_pre: Tuple[np.ndarray, np.ndarray, np.ndarray] = np.where(self.gt_results_arr == self.min_gt_result)
#    1523     return tuple([arr[0] for arr in where_min_pre])
#
# File ~/Documents/occam/invisible-map-generation/map_processing/data_models.py:1462, in OSweepResults.gt_results_arr(self)
#    1460 @property
#    1461 def gt_results_arr(self) -> np.ndarray:
# -> 1462     return np.array(self.gt_results_list).reshape(self.gt_results_arr_shape, order="C")
#
# ValueError: cannot reshape array of size 950 into shape (10,10,10)

# %%
run_sweep(big_map_name, 1)
# Out:
# Generating list of optimization sweeping parameters...
# 1000 parameters generated for sweeping
# Starting multi-process optimization parameter sweep (with 8 processes)...
#   0%|          | 0/1000 [00:00<?, ?it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   0%|          | 4/1000 [00:09<27:46,  1.67s/it]  /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   1%|          | 11/1000 [00:25<34:20,  2.08s/it]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# 100%|██████████| 1000/1000 [19:58<00:00,  1.20s/it]
# Pre-Optimization GT: 0.06674587320954306
# Best GT: 0.0606968368675149 (delta: -0.006049036342028163
# Best Alpha: inf
# Pre-Optimization GT: 0.06674587320954306
# For map based on min alpha, GT: 0.08182594994885412 (delta = 0.015080076739311055)
# For map based on min gt, GT: 0.0606968368675149 (delta = -0.006049036342028163)
# For map based on min shift, GT: 0.06199366045723702 (delta = -0.0047522127523060426)
# Min Shift Metric: 0.10990276935748274
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 4.1e+12
# >       alpha_all_before: inf
# > se3_not_gravity_before: 4.1e+12
# >          psi2uv_before: 0
# >         gravity_before: 2.5e-12
# ---------------------------------
# >         chi2_all_after: 2.7e+06
# >        alpha_all_after: inf
# >  se3_not_gravity_after: 2.7e+06
# >           psi2uv_after: 0
# >          gravity_after: 0.028
#
# Fitness metrics (Alpha):
# >        chi2_all_before: 4.2e+14
# >       alpha_all_before: inf
# > se3_not_gravity_before: 4.2e+14
# >          psi2uv_before: 0
# >         gravity_before: 2.5e-12
# ---------------------------------
# >         chi2_all_after: 3.3e+12
# >        alpha_all_after: inf
# >  se3_not_gravity_after: 3.3e+12
# >           psi2uv_after: 0
# >          gravity_after: 0.4
# Maximum ground truth metric: 0.14471435775447777 (tag id: 311.0)
# Ground Truth per Tag:
#  {300.0: 0.022489171089814755, 301.0: 0.03842710404258372, 304.0: 0.023209934825907767, 305.0: 0.025964025162357653, 306.0: 0.03836610442450743, 307.0: 0.03242780377069972, 308.0: 0.04939167350456358, 309.0: 0.06101312486966357, 310.0: 0.11723188570660789, 311.0: 0.14471435775447777, 312.0: 0.07870901923675386, 313.0: 0.049989257547176855, 320.0: 0.04723313894695709, 321.0: 0.10854433473624302, 322.0: 0.07191395722263723, 323.0: 0.09224837707915012, 324.0: 0.029972956827651238}
#
#
# Rotation metric (GT): [0.88240882 1.46678101 1.07153027]
# Maximum rotation (GT): [5.92138464 4.44130438 4.93590392] (tag id: 310.0)
# Rotation metric (Alpha): [1.06106232 2.50806003 0.54405189]
# Maximum rotation (Alpha): [10.17360597 16.14138356  4.09250585] (tag id: 323.0)

# %% [markdown]
# The next experiment is to extrapolate the parameters of one optimized map and apply them to another map. This extrapolated optimization is compared to the best possible optimization on that map. To start, the optimized hyperparameters of the small map are being applied to that of the big map, using a no SBA parameter sweep.

# %%
extrapolate_parameters(small_map_name, big_map_name, 1)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   0%|          | 1/1000 [00:03<55:10,  3.31s/it]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   0%|          | 5/1000 [00:05<11:54,  1.39it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   1%|          | 7/1000 [00:07<15:54,  1.04it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   1%|          | 8/1000 [00:08<14:53,  1.11it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   1%|          | 10/1000 [00:09<13:59,  1.18it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#   1%|          | 11/1000 [00:10<12:19,  1.34it/s]/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/graph_opt_utils.py:185: RuntimeWarning: divide by zero encountered in log
#   alpha: float = c - np.log(np.sqrt(np.linalg.det(information))) + 0.5 * chi2
#  20%|█▉        | 196/1000 [03:03<11:34,  1.16it/s]
# PYDANTIC ERROR
#  32%|███▏      | 320/1000 [04:04<04:08,  2.74it/s]
# PYDANTIC ERROR
#  40%|███▉      | 399/1000 [04:34<03:36,  2.78it/s]
# PYDANTIC ERROR
#  44%|████▍     | 443/1000 [04:51<04:10,  2.22it/s]
# PYDANTIC ERROR
#  50%|████▉     | 498/1000 [05:11<03:34,  2.34it/s]
# PYDANTIC ERROR
#  51%|█████     | 509/1000 [05:15<03:15,  2.51it/s]
# PYDANTIC ERROR
#  52%|█████▏    | 520/1000 [05:20<03:57,  2.02it/s]
# PYDANTIC ERROR
#  56%|█████▋    | 564/1000 [05:37<03:36,  2.01it/s]
# PYDANTIC ERROR
#  60%|██████    | 600/1000 [05:50<02:06,  3.17it/s]
# PYDANTIC ERROR
#  60%|██████    | 602/1000 [05:51<02:03,  3.22it/s]
# PYDANTIC ERROR
#  61%|██████    | 610/1000 [05:54<02:22,  2.73it/s]
# PYDANTIC ERROR
#  61%|██████▏   | 613/1000 [05:55<02:09,  2.99it/s]
# PYDANTIC ERROR
#  62%|██████▏   | 618/1000 [05:57<01:50,  3.47it/s]
# PYDANTIC ERROR
#  62%|██████▏   | 621/1000 [05:58<03:25,  1.85it/s]
# PYDANTIC ERROR
#  63%|██████▎   | 632/1000 [06:02<01:54,  3.21it/s]
# PYDANTIC ERROR
#  64%|██████▍   | 644/1000 [06:06<02:07,  2.80it/s]
# PYDANTIC ERROR
#  70%|███████   | 701/1000 [06:29<01:30,  3.31it/s]
# PYDANTIC ERROR
#  70%|███████   | 703/1000 [06:30<01:37,  3.05it/s]
# PYDANTIC ERROR
#  71%|███████   | 712/1000 [06:33<01:32,  3.12it/s]
# PYDANTIC ERROR
#  71%|███████▏  | 714/1000 [06:34<01:35,  2.99it/s]
# PYDANTIC ERROR
#  72%|███████▏  | 719/1000 [06:36<01:59,  2.35it/s]
# PYDANTIC ERROR
#  72%|███████▎  | 725/1000 [06:38<01:02,  4.39it/s]
# PYDANTIC ERROR
#  73%|███████▎  | 729/1000 [06:39<01:23,  3.24it/s]
# PYDANTIC ERROR
#  73%|███████▎  | 732/1000 [06:41<02:17,  1.94it/s]
# PYDANTIC ERROR
#  74%|███████▍  | 744/1000 [06:46<02:10,  1.97it/s]
# PYDANTIC ERROR
#  74%|███████▍  | 745/1000 [06:46<01:48,  2.35it/s]
#  75%|███████▌  | 754/1000 [06:49<01:28,  2.78it/s]
# PYDANTIC ERROR
#  77%|███████▋  | 767/1000 [06:55<01:26,  2.71it/s]
# PYDANTIC ERROR
#  80%|████████  | 801/1000 [07:09<01:09,  2.85it/s]
# PYDANTIC ERROR
#  80%|████████  | 804/1000 [07:10<00:48,  4.01it/s]
# PYDANTIC ERROR
#  81%|████████  | 808/1000 [07:12<01:39,  1.93it/s]
# PYDANTIC ERROR
#  82%|████████▏ | 816/1000 [07:14<00:43,  4.23it/s]
# PYDANTIC ERROR
#  82%|████████▏ | 821/1000 [07:17<01:42,  1.75it/s]
# PYDANTIC ERRORPYDANTIC ERROR
#  83%|████████▎ | 832/1000 [07:21<01:25,  1.96it/s]
# PYDANTIC ERROR
#  84%|████████▎ | 836/1000 [07:23<01:00,  2.72it/s]
# PYDANTIC ERROR
#  84%|████████▎ | 837/1000 [07:23<00:51,  3.19it/s]
#  84%|████████▍ | 843/1000 [07:26<01:13,  2.12it/s]
# PYDANTIC ERROR
#  85%|████████▌ | 854/1000 [07:30<00:53,  2.74it/s]
# PYDANTIC ERROR
#  86%|████████▋ | 864/1000 [07:34<01:01,  2.22it/s]
# PYDANTIC ERROR
#  90%|█████████ | 901/1000 [07:50<00:31,  3.12it/s]
# PYDANTIC ERROR
#  90%|█████████ | 903/1000 [07:51<00:29,  3.30it/s]
# PYDANTIC ERROR
#  91%|█████████ | 910/1000 [07:54<00:37,  2.39it/s]
# PYDANTIC ERROR
#  91%|█████████▏| 913/1000 [07:55<00:29,  2.92it/s]
# PYDANTIC ERROR
#  92%|█████████▏| 920/1000 [07:58<00:41,  1.94it/s]
# PYDANTIC ERROR
#  92%|█████████▏| 924/1000 [07:59<00:25,  3.01it/s]
# PYDANTIC ERROR
#  93%|█████████▎| 930/1000 [08:02<00:31,  2.24it/s]
# PYDANTIC ERROR
#  93%|█████████▎| 934/1000 [08:04<00:27,  2.41it/s]
# PYDANTIC ERROR
#  94%|█████████▎| 936/1000 [08:04<00:17,  3.65it/s]
#  94%|█████████▍| 942/1000 [08:06<00:24,  2.41it/s]
# PYDANTIC ERROR
#  95%|█████████▌| 954/1000 [08:11<00:22,  2.05it/s]
# PYDANTIC ERROR
#  97%|█████████▋| 966/1000 [08:16<00:13,  2.45it/s]
# PYDANTIC ERROR
# 100%|██████████| 1000/1000 [08:29<00:00,  1.96it/s]
# Pre-Optimization GT: 0.08594258312404719
# Best GT: 0.07922716107554384 (delta: -0.006715422048503353
# Best Alpha: inf
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_11079/1550759980.py", line 1, in <module>
#     extrapolate_parameters(small_map_name, big_map_name, 1)
#   File "/home/achakraborty/Documents/occam/invisible-map-generation/run_scripts/run.py", line 91, in extrapolate_parameters
#   File "/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/sweep.py", line 230, in sweep_params
#     print("Parameters (GT):\n" + json.dumps(sweep_results.args_producing_min, indent=2))
#   File "/home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py", line 1538, in args_producing_min
#     args_producing_min[key] = np.array(self.sweep_config[key])[self.where_min[i]]
# IndexError: index 113 is out of bounds for axis 0 with size 10
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/home/achakraborty/.local/lib/python3.8/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %% [markdown]
# Next, the hyperparameters of the big map are being applied to that of the small map in a no SBA parameter sweep.

# %%
extrapolate_parameters(big_map_name, small_map_name, 1)
# Out:
# 100%|██████████| 1000/1000 [15:33<00:00,  1.07it/s]
# Pre-Optimization GT: 0.05688717829300238
# Best GT: 0.05504550329068185 (delta: -0.0018416750023205336
# Best Alpha: -98699.41217041023
# Parameters (GT):
# {
#   "lin_vel_var": 1e-10,
#   "ang_vel_var": 4.641588833612782e-07,
#   "tag_var": 10.0
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 1.3e+13
# >       alpha_all_before: 6.3e+12
# > se3_not_gravity_before: 1.3e+13
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ---------------------------------
# >         chi2_all_after: 5.5e+06
# >        alpha_all_after: 2.6e+06
# >  se3_not_gravity_after: 5.5e+06
# >           psi2uv_after: 0
# >          gravity_after: 0.11
# 100%|██████████| 1000/1000 [08:50<00:00,  1.89it/s]
# Pre-Optimization GT: 0.07506990471281554
# Best GT: 0.0733349319320337 (delta: -0.0017349727807818294
# Best Alpha: -69155.77465903823
# Parameters (GT):
# {
#   "lin_vel_var": 0.0359381366380464,
#   "ang_vel_var": 1e-10,
#   "tag_var": 10.0
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 4.7e+06
# >       alpha_all_before: 2.3e+06
# > se3_not_gravity_before: 4.7e+06
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 7.9e+04
# >        alpha_all_after: -2.7e+04
# >  se3_not_gravity_after: 7.9e+04
# >           psi2uv_after: 0
# >          gravity_after: 3.8e-06
# 0
# Pre-Optimization GT: 0.07506990471281554
# Best GT: 0.07442671941825539 (delta: -0.0006431852945601446
# Best Alpha: 689783.0089156234
# Parameters (GT):
# {
#   "lin_vel_var": 1e-10,
#   "ang_vel_var": 4.641588833612782e-07,
#   "tag_var": 10.0
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 1.1e+12
# >       alpha_all_before: 5.3e+11
# > se3_not_gravity_before: 1.1e+12
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ---------------------------------
# >         chi2_all_after: 1.6e+06
# >        alpha_all_after: 6.9e+05
# >  se3_not_gravity_after: 1.6e+06
# >           psi2uv_after: 0
# >          gravity_after: 0.011
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1634: UserWarning: Attempting to set identical left == right == 1e-10 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1637: UserWarning: Attempting to set identical bottom == top == 4.641588833612782e-07 results in singular transformations; automatically expanding.
#   ax.set_ylim(bottom=np.min(y_vec), top=np.max(y_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1637: UserWarning: Attempting to set identical bottom == top == 10.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(bottom=np.min(y_vec), top=np.max(y_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1634: UserWarning: Attempting to set identical left == right == 4.641588833612782e-07 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# Extrapolated gt: 0.07442671941825539
# Full Sweep gt: 0.0733349319320337
