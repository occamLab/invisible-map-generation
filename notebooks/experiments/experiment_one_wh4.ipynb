# %% [markdown]
# # Experiment One (WH4)
# The purpose of this experiment is to evaluate the relative accuracy and success rate of the tuned hyperparameters for a given map. This evaluation will be done in three main methods:
# 1. Determine the lowest ground truth value for a given map based on a parameter sweep.
# 2. Determine if the tuned hyperparameters of one map can be extrapolated to that of another map that either contains this map or is contained within this map.
# 3. Determine if there is a smooth relationship between a swept hyperparameter and the ground truth data.
#
# Each of these specific tests will be conducted twice - once with SBA optimization and once without.

# %% [markdown]
# Run the following script to set up the notebook environment before running any other code cells.

# %%
# %cd ../..
import os
import sys
sys.path.append(os.getcwd() + "/../..")
from run_scripts.run import extrapolate_parameters, run_sweep
small_map_name = '4_lou_to_rich_room*'
big_map_name = 'p1_WH4_2.json*'
# Out:
# /home/achakraborty/Documents/occam/invisible-map-generation

# %% [markdown]
# The first test being conducted is determining the minimum ground truth of an optimized map with a no SBA optimization. This is being done on both, a small map and a large map.

# %%
run_sweep(small_map_name, 1)
# Out:
# Generating list of optimization sweeping parameters...
# 1000 parameters generated for sweeping
# Starting multi-process optimization parameter sweep (with 8 processes)...
# 100%|██████████| 1000/1000 [08:32<00:00,  1.95it/s]
# Pre-Optimization GT: 0.07506990471281554
# Best GT: 0.0733349319320337 (delta: -0.0017349727807818294
# Best Alpha: -69155.77465903817
# Pre-Optimization GT: 0.07506990471281554
# For map based on min alpha, GT: 0.15550067039078014 (delta = 0.0804307656779646)
# For map based on min gt, GT: 0.0733349319320337 (delta = -0.0017349727807818294)
# For map based on min shift, GT: 0.07688625429785513 (delta = 0.001816349585039595)
# Min Shift Metric: 0.02799546720699096
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 4.7e+06
# >       alpha_all_before: 2.3e+06
# > se3_not_gravity_before: 4.7e+06
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 7.9e+04
# >        alpha_all_after: -2.7e+04
# >  se3_not_gravity_after: 7.9e+04
# >           psi2uv_after: 0
# >          gravity_after: 3.8e-06
#
# Fitness metrics (Alpha):
# >        chi2_all_before: 1.8e+07
# >       alpha_all_before: 9.1e+06
# > se3_not_gravity_before: 1.8e+07
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 3.7e+04
# >        alpha_all_after: -6.9e+04
# >  se3_not_gravity_after: 3.7e+04
# >           psi2uv_after: 0
# >          gravity_after: 0.38
# Maximum ground truth metric: 0.23382762374591248 (tag id: 316.0)
# Ground Truth per Tag:
#  {316.0: 0.23382762374591248, 323.0: 0.03354930222675052, 324.0: 0.0333817593533023, 325.0: 0.03216744141624575, 326.0: 0.050721475535153125, 327.0: 0.04853897974257418, 329.0: 0.08115794150429761}
#
#
# Rotation metric (GT): [1.14148599 1.26576826 1.04249983]
# Maximum rotation (GT): [7.42821554 6.66200871 5.49450391] (tag id: 329.0)
# Rotation metric (Alpha): [2.41491106 1.69443073 6.63443872]
# Maximum rotation (Alpha): [11.41399646  3.67966218 20.03171957] (tag id: 329.0)

# %%
run_sweep(big_map_name, 1)
# Out:
# Generating list of optimization sweeping parameters...
# 1000 parameters generated for sweeping
# Starting multi-process optimization parameter sweep (with 8 processes)...
# 100%|██████████| 1000/1000 [14:06<00:00,  1.18it/s]
# Pre-Optimization GT: 0.05688717829300238
# Best GT: 0.05504550329068185 (delta: -0.0018416750023205336
# Best Alpha: -98699.41217041036
# Pre-Optimization GT: 0.05688717829300238
# For map based on min alpha, GT: 0.12648715770209557 (delta = 0.06959997940909318)
# For map based on min gt, GT: 0.05504550329068185 (delta = -0.0018416750023205336)
# For map based on min shift, GT: 0.05504550329068185 (delta = -0.0018416750023205336)
# Min Shift Metric: 0.0398375799622134
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 1.3e+13
# >       alpha_all_before: 6.3e+12
# > se3_not_gravity_before: 1.3e+13
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ---------------------------------
# >         chi2_all_after: 5.5e+06
# >        alpha_all_after: 2.6e+06
# >  se3_not_gravity_after: 5.5e+06
# >           psi2uv_after: 0
# >          gravity_after: 0.11
#
# Fitness metrics (Alpha):
# >        chi2_all_before: 1.9e+08
# >       alpha_all_before: 9.4e+07
# > se3_not_gravity_before: 1.9e+08
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ----------------------------------
# >         chi2_all_after: 4.7e+04
# >        alpha_all_after: -9.9e+04
# >  se3_not_gravity_after: 4.7e+04
# >           psi2uv_after: 0
# >          gravity_after: 3.6
# Maximum ground truth metric: 0.21821359991480427 (tag id: 316)
# Ground Truth per Tag:
#  {311: 0.04544648558387257, 312: 0.05617867444475747, 313: 0.05704081218488138, 314: 0.11162664127983911, 315: 0.023012608263074465, 316: 0.21821359991480427, 317: 0.02592796363628795, 318: 0.02677548096135957, 319: 0.061034426965114456, 320: 0.0623770037148188, 321: 0.030087667272727357, 322: 0.05027823198667883, 323: 0.026078696931464508, 324: 0.03795196398519357, 325: 0.03196409877244956, 326: 0.05207620900570677, 327: 0.03534659304248063, 328: 0.05037484135892195, 329: 0.04407256321852207}
#
#
# Rotation metric (GT): [0.44873686 0.40826853 0.45522353]
# Maximum rotation (GT): [1.83878714 1.1214031  1.42403967] (tag id: 322.0)
# Rotation metric (Alpha): [1.61901711 3.58435186 5.94492235]
# Maximum rotation (Alpha): [10.04762871 18.19548131 21.3410752 ] (tag id: 321.0)

# %% [markdown]
# The next experiment is to extrapolate the parameters of one optimized map and apply them to another map. This extrapolated optimization is compared to the best possible optimization on that map. To start, the optimized hyperparameters of the small map are being applied to that of the big map, using a no SBA parameter sweep.

# %%
extrapolate_parameters(small_map_name, big_map_name, 1)
# Out:
# 100%|██████████| 1000/1000 [08:42<00:00,  1.91it/s]
# Pre-Optimization GT: 0.07506990471281554
# Best GT: 0.0733349319320337 (delta: -0.0017349727807818294
# Best Alpha: -69155.77465903839
# Parameters (GT):
# {
#   "lin_vel_var": 0.0359381366380464,
#   "ang_vel_var": 1.6681005372000556e-09,
#   "tag_var": 1e-10
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 4.7e+06
# >       alpha_all_before: 2.3e+06
# > se3_not_gravity_before: 4.7e+06
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 7.9e+04
# >        alpha_all_after: -2.7e+04
# >  se3_not_gravity_after: 7.9e+04
# >           psi2uv_after: 0
# >          gravity_after: 3.8e-06
# 100%|██████████| 1000/1000 [14:31<00:00,  1.15it/s]
# Pre-Optimization GT: 0.05688717829300238
# Best GT: 0.05504550329068185 (delta: -0.0018416750023205336
# Best Alpha: -98699.41217040976
# Parameters (GT):
# {
#   "lin_vel_var": 1e-10,
#   "ang_vel_var": 7.742636826811277e-06,
#   "tag_var": 1e-10
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 1.3e+13
# >       alpha_all_before: 6.3e+12
# > se3_not_gravity_before: 1.3e+13
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ---------------------------------
# >         chi2_all_after: 5.5e+06
# >        alpha_all_after: 2.6e+06
# >  se3_not_gravity_after: 5.5e+06
# >           psi2uv_after: 0
# >          gravity_after: 0.11
# 0
# Pre-Optimization GT: 0.05688717829300238
# Best GT: 0.06728559395493805 (delta: 0.010398415661935667
# Best Alpha: 8357486903899092.0
# Parameters (GT):
# {
#   "lin_vel_var": 0.0359381366380464,
#   "ang_vel_var": 1.6681005372000556e-09,
#   "tag_var": 1e-10
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 2.5e+18
# >       alpha_all_before: 1.2e+18
# > se3_not_gravity_before: 2.5e+18
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ---------------------------------
# >         chi2_all_after: 1.7e+16
# >        alpha_all_after: 8.4e+15
# >  se3_not_gravity_after: 1.7e+16
# >           psi2uv_after: 0
# >          gravity_after: 0.76
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1634: UserWarning: Attempting to set identical left == right == 0.0359381366380464 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1637: UserWarning: Attempting to set identical bottom == top == 1.6681005372000556e-09 results in singular transformations; automatically expanding.
#   ax.set_ylim(bottom=np.min(y_vec), top=np.max(y_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1637: UserWarning: Attempting to set identical bottom == top == 1e-10 results in singular transformations; automatically expanding.
#   ax.set_ylim(bottom=np.min(y_vec), top=np.max(y_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1634: UserWarning: Attempting to set identical left == right == 1.6681005372000556e-09 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# Extrapolated gt: 0.06728559395493805
# Full Sweep gt: 0.05504550329068185

# %% [markdown]
# Next, the hyperparameters of the big map are being applied to that of the small map in a no SBA parameter sweep.

# %%
extrapolate_parameters(big_map_name, small_map_name, 1)
# Out:
# 100%|██████████| 1000/1000 [15:33<00:00,  1.07it/s]
# Pre-Optimization GT: 0.05688717829300238
# Best GT: 0.05504550329068185 (delta: -0.0018416750023205336
# Best Alpha: -98699.41217041023
# Parameters (GT):
# {
#   "lin_vel_var": 1e-10,
#   "ang_vel_var": 4.641588833612782e-07,
#   "tag_var": 10.0
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 1.3e+13
# >       alpha_all_before: 6.3e+12
# > se3_not_gravity_before: 1.3e+13
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ---------------------------------
# >         chi2_all_after: 5.5e+06
# >        alpha_all_after: 2.6e+06
# >  se3_not_gravity_after: 5.5e+06
# >           psi2uv_after: 0
# >          gravity_after: 0.11
# 100%|██████████| 1000/1000 [08:50<00:00,  1.89it/s]
# Pre-Optimization GT: 0.07506990471281554
# Best GT: 0.0733349319320337 (delta: -0.0017349727807818294
# Best Alpha: -69155.77465903823
# Parameters (GT):
# {
#   "lin_vel_var": 0.0359381366380464,
#   "ang_vel_var": 1e-10,
#   "tag_var": 10.0
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 4.7e+06
# >       alpha_all_before: 2.3e+06
# > se3_not_gravity_before: 4.7e+06
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 7.9e+04
# >        alpha_all_after: -2.7e+04
# >  se3_not_gravity_after: 7.9e+04
# >           psi2uv_after: 0
# >          gravity_after: 3.8e-06
# 0
# Pre-Optimization GT: 0.07506990471281554
# Best GT: 0.07442671941825539 (delta: -0.0006431852945601446
# Best Alpha: 689783.0089156234
# Parameters (GT):
# {
#   "lin_vel_var": 1e-10,
#   "ang_vel_var": 4.641588833612782e-07,
#   "tag_var": 10.0
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 1.1e+12
# >       alpha_all_before: 5.3e+11
# > se3_not_gravity_before: 1.1e+12
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ---------------------------------
# >         chi2_all_after: 1.6e+06
# >        alpha_all_after: 6.9e+05
# >  se3_not_gravity_after: 1.6e+06
# >           psi2uv_after: 0
# >          gravity_after: 0.011
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1634: UserWarning: Attempting to set identical left == right == 1e-10 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1637: UserWarning: Attempting to set identical bottom == top == 4.641588833612782e-07 results in singular transformations; automatically expanding.
#   ax.set_ylim(bottom=np.min(y_vec), top=np.max(y_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1637: UserWarning: Attempting to set identical bottom == top == 10.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(bottom=np.min(y_vec), top=np.max(y_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1634: UserWarning: Attempting to set identical left == right == 4.641588833612782e-07 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# Extrapolated gt: 0.07442671941825539
# Full Sweep gt: 0.0733349319320337
