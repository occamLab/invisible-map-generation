# %%
# %cd ../..
import os
import sys
sys.path.append(os.getcwd() + "/../..")
from run_scripts.run import run_sweep
map_name = 'floor_2_obright*'
import os
import subprocess
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import matplotlib_inline
kpse_cp = subprocess.run(['kpsewhich', '-var-value', 'TEXMFDIST'], capture_output=True, check=True)
font_loc1 = os.path.join(kpse_cp.stdout.decode('utf8').strip(), 'fonts', 'opentype', 'public', 'tex-gyre')
print(f'loading TeX Gyre fonts from "{font_loc1}"')
font_dirs = [font_loc1]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
for font_file in font_files:
    font_manager.fontManager.addfont(font_file)

plt.rcParams['font.family'] = 'TeX Gyre Termes'
plt.rcParams["mathtext.fontset"] = "stix"

matplotlib_inline.backend_inline.set_matplotlib_formats("svg")
# Out:
# /home/achakraborty/Documents/occam/invisible-map-generation
# loading TeX Gyre fonts from "/usr/share/texlive/texmf-dist/fonts/opentype/public/tex-gyre"

# %%
run_sweep(map_name, 1)
# Out:
# Generating list of optimization sweeping parameters...
# 1000 parameters generated for sweeping
# Starting multi-process optimization parameter sweep (with 8 processes)...
# 100%|██████████| 1000/1000 [18:01<00:00,  1.08s/it]
# Pre-Optimization GT: 0.05105195133833579
# Best GT: 0.034487666692861935 (delta: -0.016564284645473853
# Best Alpha: -57075.58270402053
# Pre-Optimization GT: 0.05105195133833579
# For map based on min alpha, GT: 0.328679351692373 (delta = 0.2776274003540372)
# For map based on min gt, GT: 0.034487666692861935 (delta = -0.016564284645473853)
# For map based on min shift, GT: 0.052285507967486045 (delta = 0.0012335566291502564)
# Min Shift Metric: 0.036965604302539555
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 1.4e+17
# >       alpha_all_before: 6.9e+16
# > se3_not_gravity_before: 1.4e+17
# >          psi2uv_before: 0
# >         gravity_before: 5.3e-13
# ---------------------------------
# >         chi2_all_after: 9.9e+06
# >        alpha_all_after: 4.9e+06
# >  se3_not_gravity_after: 9.9e+06
# >           psi2uv_after: 0
# >          gravity_after: 0.011
#
# Fitness metrics (Alpha):
# >        chi2_all_before: 2.3e+07
# >       alpha_all_before: 1.1e+07
# > se3_not_gravity_before: 2.3e+07
# >          psi2uv_before: 0
# >         gravity_before: 5.3e-13
# ----------------------------------
# >         chi2_all_after: 4.1e+03
# >        alpha_all_after: -5.7e+04
# >  se3_not_gravity_after: 4.1e+03
# >           psi2uv_after: 0
# >          gravity_after: 0.091
# Maximum ground truth metric: 0.06140524028598948 (tag id: 306.0)
# Ground Truth per Tag:
#  {300.0: 0.0318432148063934, 301.0: 0.02797210712628233, 302.0: 0.023556075257117375, 303.0: 0.023102181093878005, 304.0: 0.0313871612765183, 305.0: 0.022889025543401328, 306.0: 0.06140524028598948, 307.0: 0.026639655081603694, 308.0: 0.02539534750284403, 309.0: 0.042582239505590314, 310.0: 0.03665813196255318, 311.0: 0.04847154093131734, 312.0: 0.04242146771085095, 313.0: 0.034778635362180184, 314.0: 0.05339686741333736, 315.0: 0.04030015784187979, 316.0: 0.043577397008195996, 317.0: 0.030093273373658636, 318.0: 0.040735174961336267, 319.0: 0.01872982033733449, 320.0: 0.03695330013150026, 321.0: 0.035636249247681835, 322.0: 0.03087415927589564, 323.0: 0.034303803983645166, 324.0: 0.018489440300563053}
#
#
# Rotation metric (GT): [0.15630731 4.45272356 0.16761682]
# Maximum rotation (GT): [0.40386811 7.76603678 0.59992547] (tag id: 319.0)
# Rotation metric (Alpha): [ 6.13947264  7.88944884 27.035094  ]
# Maximum rotation (Alpha): [ 27.8305093   56.01376443 178.7274077 ] (tag id: 323.0)
# Optimal Hyperparameters:
# Parameters (GT):
# {
#   "lin_vel_var": 0.00012915496650148855,
#   "ang_vel_var": 1.6681005372000556e-09,
#   "tag_var": 0.0359381366380464
# }
# Parameters (Alpha):
# {
#   "lin_vel_var": 4.641588833612782e-07,
#   "ang_vel_var": 0.002154434690031887,
#   "tag_var": 2.782559402207126e-08
# }
# Parameters (Shift):
# {
#   "lin_vel_var": 10.0,
#   "ang_vel_var": 0.5994842503189421,
#   "tag_var": 0.00012915496650148855
# }
# findfont: Font family ['TeX Gyre Termes'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['TeX Gyre Termes'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['TeX Gyre Termes'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['TeX Gyre Termes'] not found. Falling back to DejaVu Sans.
