# %% [markdown]
# # Experiment One (MAC)
# The purpose of this experiment is to evaluate the relative accuracy and success rate of the tuned hyperparameters for a given map. This evaluation will be done in three main methods:
# 1. Determine the lowest ground truth value for a given map based on a parameter sweep.
# 2. Determine if the tuned hyperparameters of one map can be extrapolated to that of another map that either contains this map or is contained within this map.
# 3. Determine if there is a smooth relationship between a swept hyperparameter and the ground truth data.
#
# Each of these specific tests will be conducted twice - once with SBA optimization and once without.

# %% [markdown]
# Run the following script to set up the notebook environment before running any other code cells.

# %%
# %cd ../..
import os
import sys
sys.path.append(os.getcwd() + "/../..")
from run_scripts.run import run_full_extrapolation
small_map_name_one = '4_lou_to_rich_room.json'
big_map_name_one = 'p1_WH4_2.json'
import os
import subprocess
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import matplotlib_inline
kpse_cp = subprocess.run(['kpsewhich', '-var-value', 'TEXMFDIST'], capture_output=True, check=True)
font_loc1 = os.path.join(kpse_cp.stdout.decode('utf8').strip(), 'fonts', 'opentype', 'public', 'tex-gyre')
print(f'loading TeX Gyre fonts from "{font_loc1}"')
font_dirs = [font_loc1]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
for font_file in font_files:
    font_manager.fontManager.addfont(font_file)

plt.rcParams['font.family'] = 'TeX Gyre Termes'
plt.rcParams["mathtext.fontset"] = "stix"

matplotlib_inline.backend_inline.set_matplotlib_formats("svg")
# Out:
# /home/achakraborty/Documents/occam/invisible-map-generation
# loading TeX Gyre fonts from "/usr/share/texlive/texmf-dist/fonts/opentype/public/tex-gyre"

# %%
run_full_extrapolation(small_map_name_one, big_map_name_one, 1)
# Out:
# Running Small Map Sweep
# Generating list of optimization sweeping parameters...
# 1000 parameters generated for sweeping
# Starting multi-process optimization parameter sweep (with 12 processes)...
# 100%|██████████| 1000/1000 [22:20<00:00,  1.34s/it]
# Pre-Optimization GT: 0.07506990471281554
# Best GT: 0.058822685881732166 (delta: -0.01624721883108337
# Best Alpha: -85839.56489072036
# Pre-Optimization GT: 0.07506990471281554
# For map based on min alpha, GT: 0.2229117771625018 (delta = 0.14784187244968627)
# For map based on min gt, GT: 0.058822685881732166 (delta = -0.01624721883108337)
# For map based on min shift, GT: 0.059537135486962794 (delta = -0.015532769225852741)
# Min Shift Metric: 0.01410906472497264
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 2.9e+16
# >       alpha_all_before: 1.4e+16
# > se3_not_gravity_before: 2.9e+16
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 4.4e+03
# >        alpha_all_after: -5.5e+04
# >  se3_not_gravity_after: 4.4e+03
# >           psi2uv_after: 0
# >          gravity_after: 0.055
#
# Fitness metrics (Alpha):
# >        chi2_all_before: 1.8e+07
# >       alpha_all_before: 9.1e+06
# > se3_not_gravity_before: 1.8e+07
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 1.3e+04
# >        alpha_all_after: -8.6e+04
# >  se3_not_gravity_after: 1.3e+04
# >           psi2uv_after: 0
# >          gravity_after: 0.45
# Maximum ground truth metric: 0.20605144414448076 (tag id: 316.0)
# Ground Truth per Tag:
#  {316.0: 0.20605144414448076, 323.0: 0.021068513746234172, 324.0: 0.027160457704738555, 325.0: 0.02737414386085901, 326.0: 0.03093762277355092, 327.0: 0.04033673546548603, 329.0: 0.058829883476775674}
#
#
# Rotation metric (GT): [0.18957841 2.01934053 0.23735762]
# Maximum rotation (GT): [0.43139763 2.56234409 0.59278842] (tag id: 316.0)
# Rotation metric (Alpha): [ 2.84513392  5.01538168 13.19876671]
# Maximum rotation (Alpha): [ 5.62510398 18.94917675 29.89567194] (tag id: 326.0)
# Parameters (GT):
# {
#   "lin_vel_var": 0.0359381366380464,
#   "ang_vel_var": 0.00012915496650148855,
#   "tag_var": 0.00012915496650148855
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 2.9e+16
# >       alpha_all_before: 1.4e+16
# > se3_not_gravity_before: 2.9e+16
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 4.4e+03
# >        alpha_all_after: -5.5e+04
# >  se3_not_gravity_after: 4.4e+03
# >           psi2uv_after: 0
# >          gravity_after: 0.055
# findfont: Font family ['TeX Gyre Termes'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['TeX Gyre Termes'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['TeX Gyre Termes'] not found. Falling back to DejaVu Sans.
# Running Big Map Sweep
# Generating list of optimization sweeping parameters...
# 1000 parameters generated for sweeping
# Starting multi-process optimization parameter sweep (with 12 processes)...
#  91%|█████████ | 911/1000 [42:08<02:53,  1.95s/it]
# CHOLMOD warning: not positive definite. file: ../Cholesky/t_cholmod_rowfac.c line: 430
# Cholesky failure, writing debug.txt (Hessian loadable by Octave)
# 100%|██████████| 1000/1000 [46:34<00:00,  2.79s/it]
# Pre-Optimization GT: 0.05688717829300238
# Best GT: 0.04896211276415834 (delta: -0.00792506552884404
# Best Alpha: -121490.54202391916
# Pre-Optimization GT: 0.05688717829300238
# For map based on min alpha, GT: 0.18145018285646108 (delta = 0.1245630045634587)
# For map based on min gt, GT: 0.04896211276415834 (delta = -0.00792506552884404)
# For map based on min shift, GT: 0.05011937740745517 (delta = -0.006767800885547209)
# Min Shift Metric: 0.02972691355780013
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 6.8e+09
# >       alpha_all_before: 3.4e+09
# > se3_not_gravity_before: 6.8e+09
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ----------------------------------
# >         chi2_all_after: 0.08
# >        alpha_all_after: -6.7e+03
# >  se3_not_gravity_after: 0.078
# >           psi2uv_after: 0
# >          gravity_after: 0.0026
#
# Fitness metrics (Alpha):
# >        chi2_all_before: 1.9e+08
# >       alpha_all_before: 9.4e+07
# > se3_not_gravity_before: 1.9e+08
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ----------------------------------
# >         chi2_all_after: 1.5e+04
# >        alpha_all_after: -1.2e+05
# >  se3_not_gravity_after: 1.5e+04
# >           psi2uv_after: 0
# >          gravity_after: 3.9
# Maximum ground truth metric: 0.21618070130918587 (tag id: 316)
# Ground Truth per Tag:
#  {311: 0.041178477147942795, 312: 0.05283328851274706, 313: 0.052116002934896176, 314: 0.11002505780733492, 315: 0.019263222468242903, 316: 0.21618070130918587, 317: 0.02159837559542542, 318: 0.02347393314147209, 319: 0.05406997764769213, 320: 0.05603857584648401, 321: 0.023056650272221275, 322: 0.01727589583837412, 323: 0.016400936812767893, 324: 0.021807914696361466, 325: 0.027721770765216123, 326: 0.05809559039842175, 327: 0.03800000635191025, 328: 0.0417866677024452, 329: 0.039357097269867136}
#
#
# Rotation metric (GT): [0.00925521 0.46114925 0.09636862]
# Maximum rotation (GT): [0.02514117 1.42032517 0.32760588] (tag id: 323.0)
# Rotation metric (Alpha): [ 4.74732298  3.35113991 13.78471259]
# Maximum rotation (Alpha): [33.49522286 14.66917424 93.85025959] (tag id: 321.0)
# Parameters (GT):
# {
#   "lin_vel_var": 10.0,
#   "ang_vel_var": 0.5994842503189421,
#   "tag_var": 10.0
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 6.8e+09
# >       alpha_all_before: 3.4e+09
# > se3_not_gravity_before: 6.8e+09
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ----------------------------------
# >         chi2_all_after: 0.08
# >        alpha_all_after: -6.7e+03
# >  se3_not_gravity_after: 0.078
# >           psi2uv_after: 0
# >          gravity_after: 0.0026
# Extapolating to small map
# Generating list of optimization sweeping parameters...
# 1 parameters generated for sweeping
# Starting single-process optimization parameter sweep...
# 0
# Pre-Optimization GT: 0.07506990471281554
# Best GT: 0.06266550500811877 (delta: -0.01240439970469677
# Best Alpha: -1287.0648246423216
# Pre-Optimization GT: 0.07506990471281554
# For map based on min alpha, GT: 0.06266550500811877 (delta = -0.01240439970469677)
# For map based on min gt, GT: 0.06266550500811877 (delta = -0.01240439970469677)
# For map based on min shift, GT: 0.06266550500811877 (delta = -0.01240439970469677)
# Min Shift Metric: 0.042922466200456956
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 4.8e+06
# >       alpha_all_before: 2.4e+06
# > se3_not_gravity_before: 4.8e+06
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 0.023
# >        alpha_all_after: -1.3e+03
# >  se3_not_gravity_after: 0.023
# >           psi2uv_after: 0
# >          gravity_after: 0.00043
#
# Fitness metrics (Alpha):
# >        chi2_all_before: 4.8e+06
# >       alpha_all_before: 2.4e+06
# > se3_not_gravity_before: 4.8e+06
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 0.023
# >        alpha_all_after: -1.3e+03
# >  se3_not_gravity_after: 0.023
# >           psi2uv_after: 0
# >          gravity_after: 0.00043
# Maximum ground truth metric: 0.2327494702283829 (tag id: 316.0)
# Ground Truth per Tag:
#  {316.0: 0.2327494702283829, 323.0: 0.02339360885430263, 324.0: 0.03079432242493423, 325.0: 0.0295441768083438, 326.0: 0.050604422182635035, 327.0: 0.043887431856288954, 329.0: 0.027685102701943794}
#
#
# Rotation metric (GT): [0.05136705 3.12946842 0.14742388]
# Maximum rotation (GT): [0.11040894 4.143256   0.42263034] (tag id: 324.0)
# Rotation metric (Alpha): [0.05136705 3.12946842 0.14742388]
# Maximum rotation (Alpha): [0.11040894 4.143256   0.42263034] (tag id: 324.0)
# Parameters (GT):
# {
#   "lin_vel_var": 10.0,
#   "ang_vel_var": 0.5994842503189421,
#   "tag_var": 10.0
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 4.8e+06
# >       alpha_all_before: 2.4e+06
# > se3_not_gravity_before: 4.8e+06
# >          psi2uv_before: 0
# >         gravity_before: 1.2e-12
# ----------------------------------
# >         chi2_all_after: 0.023
# >        alpha_all_after: -1.3e+03
# >  se3_not_gravity_after: 0.023
# >           psi2uv_after: 0
# >          gravity_after: 0.00043
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1636: UserWarning: Attempting to set identical left == right == 10.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1639: UserWarning: Attempting to set identical bottom == top == 0.5994842503189421 results in singular transformations; automatically expanding.
#   ax.set_ylim(bottom=np.min(y_vec), top=np.max(y_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1639: UserWarning: Attempting to set identical bottom == top == 10.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(bottom=np.min(y_vec), top=np.max(y_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1636: UserWarning: Attempting to set identical left == right == 0.5994842503189421 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# Extrapolating to big map
# Generating list of optimization sweeping parameters...
# 1 parameters generated for sweeping
# Starting single-process optimization parameter sweep...
# 0
# Pre-Optimization GT: 0.05688717829300238
# Best GT: 0.04933299768872168 (delta: -0.0075541806042807025
# Best Alpha: -67919.89682440367
# Pre-Optimization GT: 0.05688717829300238
# For map based on min alpha, GT: 0.04933299768872168 (delta = -0.0075541806042807025)
# For map based on min gt, GT: 0.04933299768872168 (delta = -0.0075541806042807025)
# For map based on min shift, GT: 0.04933299768872168 (delta = -0.0075541806042807025)
# Min Shift Metric: 0.03897741859605826
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 1.9e+12
# >       alpha_all_before: 9.5e+11
# > se3_not_gravity_before: 1.9e+12
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ----------------------------------
# >         chi2_all_after: 1e+03
# >        alpha_all_after: -6.8e+04
# >  se3_not_gravity_after: 1e+03
# >           psi2uv_after: 0
# >          gravity_after: 0.012
#
# Fitness metrics (Alpha):
# >        chi2_all_before: 1.9e+12
# >       alpha_all_before: 9.5e+11
# > se3_not_gravity_before: 1.9e+12
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ----------------------------------
# >         chi2_all_after: 1e+03
# >        alpha_all_after: -6.8e+04
# >  se3_not_gravity_after: 1e+03
# >           psi2uv_after: 0
# >          gravity_after: 0.012
# Maximum ground truth metric: 0.21693608801632738 (tag id: 316)
# Ground Truth per Tag:
#  {311: 0.04117085003610956, 312: 0.05371169379107469, 313: 0.052590820632480884, 314: 0.11073067013697797, 315: 0.0201699477202597, 316: 0.21693608801632738, 317: 0.021685488562358593, 318: 0.0236651586679914, 319: 0.05514335431700012, 320: 0.05578103491942564, 321: 0.02062748182799039, 322: 0.018510190971514948, 323: 0.016933142163199806, 324: 0.02284996083414099, 325: 0.0288439431982504, 326: 0.057720925766940274, 327: 0.038108779909881235, 328: 0.0420422487402724, 329: 0.04010517587351554}
#
#
# Rotation metric (GT): [0.0685188  0.41896974 0.15559952]
# Maximum rotation (GT): [0.20720742 1.68513358 0.44185078] (tag id: 323.0)
# Rotation metric (Alpha): [0.0685188  0.41896974 0.15559952]
# Maximum rotation (Alpha): [0.20720742 1.68513358 0.44185078] (tag id: 323.0)
# Parameters (GT):
# {
#   "lin_vel_var": 0.0359381366380464,
#   "ang_vel_var": 0.00012915496650148855,
#   "tag_var": 0.00012915496650148855
# }
#
#
# Fitness metrics (GT):
# >        chi2_all_before: 1.9e+12
# >       alpha_all_before: 9.5e+11
# > se3_not_gravity_before: 1.9e+12
# >          psi2uv_before: 0
# >         gravity_before: 2.2e-12
# ----------------------------------
# >         chi2_all_after: 1e+03
# >        alpha_all_after: -6.8e+04
# >  se3_not_gravity_after: 1e+03
# >           psi2uv_after: 0
# >          gravity_after: 0.012
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1636: UserWarning: Attempting to set identical left == right == 0.0359381366380464 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1639: UserWarning: Attempting to set identical bottom == top == 0.00012915496650148855 results in singular transformations; automatically expanding.
#   ax.set_ylim(bottom=np.min(y_vec), top=np.max(y_vec))
# /home/achakraborty/Documents/occam/invisible-map-generation/map_processing/data_models.py:1636: UserWarning: Attempting to set identical left == right == 0.00012915496650148855 results in singular transformations; automatically expanding.
#   ax.set_xlim(left=np.min(x_vec), right=np.max(x_vec))
# Small Map Min GT: 0.058822685881732166
# Small Map Extrapolated GT: 0.06266550500811877
# Big Map Min GT: 0.04896211276415834
# Big Map Extrapolated GT: 0.04933299768872168
